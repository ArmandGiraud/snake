# %%
# %load_ext autoreload
# %autoreload 2
# %config Completer.use_jedi = False
sizes = (10, 10)
from utils import build_grille, initial_snake, run, initialize_snake, Snake
from pprint import pprint
from IPython.display import clear_output
grille = build_grille(sizes)
grille_intialized = initialize_snake(grille, sizes)
import matplotlib.pyplot as plt
#snake = initial_snake(high)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
sn = Snake(sizes, None)
grille = sn.reset()
#state = preprocess_grille(state, to_cnn=True)
game_iterator = sn.play()
step = 0
while True:
    #clear_output()
    step+=1
    plt.matshow(grille)
    plt.show()
    reward, grille, user_action, is_done = next(game_iterator)
    print("Step:", step, "reward:", reward)

    if is_done:
        break
# Out:
# Move:6
# Step: 1 reward: 1
# Move:6
# Step: 2 reward: 1
# Move:5
# Step: 3 reward: 1
# Move:5
# Step: 4 reward: 1
# Move:5
# Step: 5 reward: 1
# Move:5
# Step: 6 reward: 5
# Move:5
# Step: 7 reward: 1
# Move:6
# Step: 8 reward: 1
# Move:6
# Step: 9 reward: 1
# Move:6
# Step: 10 reward: 5
# Move:6
# Step: 11 reward: 1
# Move:8
# Step: 12 reward: 1
# Move:8
# Step: 13 reward: 1
# Move:8
# Step: 14 reward: 1
# Move:8
# Step: 15 reward: 1
# Move:8
# Step: 16 reward: 1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-42-ee786e8520a0> in <module>
#       9     plt.matshow(grille)
#      10     plt.show()
# ---> 11     reward, grille, user_action, is_done = next(game_iterator)
#      12     print("Step:", step, "reward:", reward)
#      13
#
# ~/snake/utils.py in play(self)
#     263         if self.bot:
#     264             bot_mode = True
# ...
